# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirudhCSE-050/AI-LAB-Sem5/blob/main/Simulated_Annealing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

def setup_chessboard(size):
    # Set up a board where each row has one randomly placed queen
    return [random.randint(0, size - 1) for _ in range(size)]

def count_queen_conflicts(chessboard):
    # Count the number of attacking queen pairs
    conflicts = 0
    n = len(chessboard)
    for i in range(n):
        for j in range(i + 1, n):
            if chessboard[i] == chessboard[j] or abs(chessboard[i] - chessboard[j]) == j - i:
                conflicts += 1
    return conflicts

def anneal_solution(size, max_steps=10000, start_temp=100, decay_factor=0.99):
    # Initialize the chessboard
    board = setup_chessboard(size)
    current_conflicts = count_queen_conflicts(board)
    temperature = start_temp

    for step in range(max_steps):
        # If no conflicts, the solution is found
        if current_conflicts == 0:
            print(f"Step {step}: Solution found!")
            print("Board State:", board)
            return board

        # Randomly pick a row and move the queen to a different column
        row = random.randint(0, size - 1)
        new_col = random.randint(0, size - 1)
        while new_col == board[row]:  # Avoid moving the queen to the same column
            new_col = random.randint(0, size - 1)

        # Create a new configuration and evaluate the conflict count
        new_board = board[:]
        new_board[row] = new_col
        new_conflicts = count_queen_conflicts(new_board)

        # Evaluate if the new configuration should be accepted
        conflict_diff = new_conflicts - current_conflicts
        if conflict_diff < 0 or math.exp(-conflict_diff / temperature) > random.random():
            board, current_conflicts = new_board, new_conflicts

        # Print current state after the iteration
        print(f"Step {step}: Temp={temperature:.2f}, Conflicts={current_conflicts}, "
              f"Conflict Change={conflict_diff}, Moving Queen at Row {row} to Column {new_col}")
        print("Board State:", board)

        # Reduce the temperature (cooling down)
        temperature *= decay_factor

    print("Solution not found within the given steps.")
    return None  # Return None if no solution was found

# Example usage
size = 8
result = anneal_solution(size)
if result:
    print("Final Solution:", result)
else:
    print("No solution found within the allowed steps.")
# Out:
# Step 0: Temp=100.00, Conflicts=6, Conflict Change=-4, Moving Queen at Row 6 to Column 3
# Board State: [2, 0, 2, 4, 2, 3, 3, 1]
# Step 1: Temp=99.00, Conflicts=7, Conflict Change=1, Moving Queen at Row 7 to Column 3
# Board State: [2, 0, 2, 4, 2, 3, 3, 3]
# Step 2: Temp=98.01, Conflicts=11, Conflict Change=4, Moving Queen at Row 3 to Column 2
# Board State: [2, 0, 2, 2, 2, 3, 3, 3]
# Step 3: Temp=97.03, Conflicts=10, Conflict Change=-1, Moving Queen at Row 5 to Column 0
# Board State: [2, 0, 2, 2, 2, 0, 3, 3]
# Step 4: Temp=96.06, Conflicts=11, Conflict Change=1, Moving Queen at Row 2 to Column 3
# Board State: [2, 0, 3, 2, 2, 0, 3, 3]
# Step 5: Temp=95.10, Conflicts=9, Conflict Change=-2, Moving Queen at Row 5 to Column 5
# Board State: [2, 0, 3, 2, 2, 5, 3, 3]
# Step 6: Temp=94.15, Conflicts=7, Conflict Change=-2, Moving Queen at Row 0 to Column 7
# Board State: [7, 0, 3, 2, 2, 5, 3, 3]
# Step 7: Temp=93.21, Conflicts=9, Conflict Change=2, Moving Queen at Row 1 to Column 3
# Board State: [7, 3, 3, 2, 2, 5, 3, 3]
# Step 8: Temp=92.27, Conflicts=9, Conflict Change=0, Moving Queen at Row 5 to Column 6
# Board State: [7, 3, 3, 2, 2, 6, 3, 3]
# Step 9: Temp=91.35, Conflicts=7, Conflict Change=-2, Moving Queen at Row 6 to Column 1
# Board State: [7, 3, 3, 2, 2, 6, 1, 3]
# Step 10: Temp=90.44, Conflicts=7, Conflict Change=0, Moving Queen at Row 5 to Column 5
# Board State: [7, 3, 3, 2, 2, 5, 1, 3]
# Step 11: Temp=89.53, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 1
# Board State: [1, 3, 3, 2, 2, 5, 1, 3]
# Step 12: Temp=88.64, Conflicts=9, Conflict Change=1, Moving Queen at Row 3 to Column 4
# Board State: [1, 3, 3, 4, 2, 5, 1, 3]
# Step 13: Temp=87.75, Conflicts=7, Conflict Change=-2, Moving Queen at Row 7 to Column 7
# Board State: [1, 3, 3, 4, 2, 5, 1, 7]
# Step 14: Temp=86.87, Conflicts=7, Conflict Change=0, Moving Queen at Row 1 to Column 0
# Board State: [1, 0, 3, 4, 2, 5, 1, 7]
# Step 15: Temp=86.01, Conflicts=7, Conflict Change=0, Moving Queen at Row 2 to Column 4
# Board State: [1, 0, 4, 4, 2, 5, 1, 7]
# Step 16: Temp=85.15, Conflicts=8, Conflict Change=1, Moving Queen at Row 4 to Column 1
# Board State: [1, 0, 4, 4, 1, 5, 1, 7]
# Step 17: Temp=84.29, Conflicts=9, Conflict Change=1, Moving Queen at Row 5 to Column 7
# Board State: [1, 0, 4, 4, 1, 7, 1, 7]
# Step 18: Temp=83.45, Conflicts=8, Conflict Change=-1, Moving Queen at Row 4 to Column 0
# Board State: [1, 0, 4, 4, 0, 7, 1, 7]
# Step 19: Temp=82.62, Conflicts=9, Conflict Change=1, Moving Queen at Row 5 to Column 4
# Board State: [1, 0, 4, 4, 0, 4, 1, 7]
# Step 20: Temp=81.79, Conflicts=8, Conflict Change=-1, Moving Queen at Row 1 to Column 3
# Board State: [1, 3, 4, 4, 0, 4, 1, 7]
# Step 21: Temp=80.97, Conflicts=8, Conflict Change=0, Moving Queen at Row 2 to Column 3
# Board State: [1, 3, 3, 4, 0, 4, 1, 7]
# Step 22: Temp=80.16, Conflicts=8, Conflict Change=0, Moving Queen at Row 2 to Column 2
# Board State: [1, 3, 2, 4, 0, 4, 1, 7]
# Step 23: Temp=79.36, Conflicts=8, Conflict Change=0, Moving Queen at Row 6 to Column 6
# Board State: [1, 3, 2, 4, 0, 4, 6, 7]
# Step 24: Temp=78.57, Conflicts=7, Conflict Change=-1, Moving Queen at Row 6 to Column 5
# Board State: [1, 3, 2, 4, 0, 4, 5, 7]
# Step 25: Temp=77.78, Conflicts=6, Conflict Change=-1, Moving Queen at Row 3 to Column 0
# Board State: [1, 3, 2, 0, 0, 4, 5, 7]
# Step 26: Temp=77.00, Conflicts=5, Conflict Change=-1, Moving Queen at Row 2 to Column 3
# Board State: [1, 3, 3, 0, 0, 4, 5, 7]
# Step 27: Temp=76.23, Conflicts=4, Conflict Change=-1, Moving Queen at Row 4 to Column 6
# Board State: [1, 3, 3, 0, 6, 4, 5, 7]
# Step 28: Temp=75.47, Conflicts=6, Conflict Change=2, Moving Queen at Row 1 to Column 0
# Board State: [1, 0, 3, 0, 6, 4, 5, 7]
# Step 29: Temp=74.72, Conflicts=7, Conflict Change=1, Moving Queen at Row 2 to Column 4
# Board State: [1, 0, 4, 0, 6, 4, 5, 7]
# Step 30: Temp=73.97, Conflicts=7, Conflict Change=0, Moving Queen at Row 2 to Column 0
# Board State: [1, 0, 0, 0, 6, 4, 5, 7]
# Step 31: Temp=73.23, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 2
# Board State: [2, 0, 0, 0, 6, 4, 5, 7]
# Step 32: Temp=72.50, Conflicts=7, Conflict Change=-1, Moving Queen at Row 3 to Column 3
# Board State: [2, 0, 0, 3, 6, 4, 5, 7]
# Step 33: Temp=71.77, Conflicts=7, Conflict Change=0, Moving Queen at Row 1 to Column 3
# Board State: [2, 3, 0, 3, 6, 4, 5, 7]
# Step 34: Temp=71.06, Conflicts=8, Conflict Change=1, Moving Queen at Row 2 to Column 3
# Board State: [2, 3, 3, 3, 6, 4, 5, 7]
# Step 35: Temp=70.34, Conflicts=9, Conflict Change=1, Moving Queen at Row 3 to Column 5
# Board State: [2, 3, 3, 5, 6, 4, 5, 7]
# Step 36: Temp=69.64, Conflicts=10, Conflict Change=1, Moving Queen at Row 2 to Column 5
# Board State: [2, 3, 5, 5, 6, 4, 5, 7]
# Step 37: Temp=68.94, Conflicts=10, Conflict Change=0, Moving Queen at Row 2 to Column 7
# Board State: [2, 3, 7, 5, 6, 4, 5, 7]
# Step 38: Temp=68.26, Conflicts=8, Conflict Change=-2, Moving Queen at Row 0 to Column 3
# Board State: [3, 3, 7, 5, 6, 4, 5, 7]
# Step 39: Temp=67.57, Conflicts=8, Conflict Change=0, Moving Queen at Row 2 to Column 2
# Board State: [3, 3, 2, 5, 6, 4, 5, 7]
# Step 40: Temp=66.90, Conflicts=8, Conflict Change=0, Moving Queen at Row 0 to Column 7
# Board State: [7, 3, 2, 5, 6, 4, 5, 7]
# Step 41: Temp=66.23, Conflicts=8, Conflict Change=0, Moving Queen at Row 7 to Column 5
# Board State: [7, 3, 2, 5, 6, 4, 5, 5]
# Step 42: Temp=65.57, Conflicts=8, Conflict Change=0, Moving Queen at Row 0 to Column 1
# Board State: [1, 3, 2, 5, 6, 4, 5, 5]
# Step 43: Temp=64.91, Conflicts=9, Conflict Change=1, Moving Queen at Row 0 to Column 0
# Board State: [0, 3, 2, 5, 6, 4, 5, 5]
# Step 44: Temp=64.26, Conflicts=10, Conflict Change=1, Moving Queen at Row 5 to Column 6
# Board State: [0, 3, 2, 5, 6, 6, 5, 5]
# Step 45: Temp=63.62, Conflicts=10, Conflict Change=0, Moving Queen at Row 4 to Column 4
# Board State: [0, 3, 2, 5, 4, 6, 5, 5]
# Step 46: Temp=62.98, Conflicts=11, Conflict Change=1, Moving Queen at Row 1 to Column 1
# Board State: [0, 1, 2, 5, 4, 6, 5, 5]
# Step 47: Temp=62.35, Conflicts=11, Conflict Change=0, Moving Queen at Row 0 to Column 5
# Board State: [5, 1, 2, 5, 4, 6, 5, 5]
# Step 48: Temp=61.73, Conflicts=12, Conflict Change=1, Moving Queen at Row 5 to Column 4
# Board State: [5, 1, 2, 5, 4, 4, 5, 5]
# Step 49: Temp=61.11, Conflicts=11, Conflict Change=-1, Moving Queen at Row 3 to Column 3
# Board State: [5, 1, 2, 3, 4, 4, 5, 5]
# Step 50: Temp=60.50, Conflicts=11, Conflict Change=0, Moving Queen at Row 7 to Column 6
# Board State: [5, 1, 2, 3, 4, 4, 5, 6]
# Step 51: Temp=59.90, Conflicts=11, Conflict Change=0, Moving Queen at Row 7 to Column 2
# Board State: [5, 1, 2, 3, 4, 4, 5, 2]
# Step 52: Temp=59.30, Conflicts=10, Conflict Change=-1, Moving Queen at Row 5 to Column 3
# Board State: [5, 1, 2, 3, 4, 3, 5, 2]
# Step 53: Temp=58.70, Conflicts=9, Conflict Change=-1, Moving Queen at Row 1 to Column 7
# Board State: [5, 7, 2, 3, 4, 3, 5, 2]
# Step 54: Temp=58.12, Conflicts=10, Conflict Change=1, Moving Queen at Row 7 to Column 4
# Board State: [5, 7, 2, 3, 4, 3, 5, 4]
# Step 55: Temp=57.54, Conflicts=5, Conflict Change=-5, Moving Queen at Row 4 to Column 6
# Board State: [5, 7, 2, 3, 6, 3, 5, 4]
# Step 56: Temp=56.96, Conflicts=6, Conflict Change=1, Moving Queen at Row 3 to Column 2
# Board State: [5, 7, 2, 2, 6, 3, 5, 4]
# Step 57: Temp=56.39, Conflicts=9, Conflict Change=3, Moving Queen at Row 4 to Column 2
# Board State: [5, 7, 2, 2, 2, 3, 5, 4]
# Step 58: Temp=55.83, Conflicts=6, Conflict Change=-3, Moving Queen at Row 3 to Column 7
# Board State: [5, 7, 2, 7, 2, 3, 5, 4]
# Step 59: Temp=55.27, Conflicts=6, Conflict Change=0, Moving Queen at Row 3 to Column 4
# Board State: [5, 7, 2, 4, 2, 3, 5, 4]
# Step 60: Temp=54.72, Conflicts=8, Conflict Change=2, Moving Queen at Row 6 to Column 4
# Board State: [5, 7, 2, 4, 2, 3, 4, 4]
# Step 61: Temp=54.17, Conflicts=9, Conflict Change=1, Moving Queen at Row 0 to Column 0
# Board State: [0, 7, 2, 4, 2, 3, 4, 4]
# Step 62: Temp=53.63, Conflicts=10, Conflict Change=1, Moving Queen at Row 7 to Column 5
# Board State: [0, 7, 2, 4, 2, 3, 4, 5]
# Step 63: Temp=53.09, Conflicts=10, Conflict Change=0, Moving Queen at Row 3 to Column 0
# Board State: [0, 7, 2, 0, 2, 3, 4, 5]
# Step 64: Temp=52.56, Conflicts=11, Conflict Change=1, Moving Queen at Row 1 to Column 0
# Board State: [0, 0, 2, 0, 2, 3, 4, 5]
# Step 65: Temp=52.03, Conflicts=10, Conflict Change=-1, Moving Queen at Row 0 to Column 4
# Board State: [4, 0, 2, 0, 2, 3, 4, 5]
# Step 66: Temp=51.51, Conflicts=8, Conflict Change=-2, Moving Queen at Row 5 to Column 1
# Board State: [4, 0, 2, 0, 2, 1, 4, 5]
# Step 67: Temp=51.00, Conflicts=10, Conflict Change=2, Moving Queen at Row 3 to Column 3
# Board State: [4, 0, 2, 3, 2, 1, 4, 5]
# Step 68: Temp=50.49, Conflicts=13, Conflict Change=3, Moving Queen at Row 1 to Column 1
# Board State: [4, 1, 2, 3, 2, 1, 4, 5]
# Step 69: Temp=49.98, Conflicts=12, Conflict Change=-1, Moving Queen at Row 1 to Column 2
# Board State: [4, 2, 2, 3, 2, 1, 4, 5]
# Step 70: Temp=49.48, Conflicts=12, Conflict Change=0, Moving Queen at Row 6 to Column 6
# Board State: [4, 2, 2, 3, 2, 1, 6, 5]
# Step 71: Temp=48.99, Conflicts=12, Conflict Change=0, Moving Queen at Row 7 to Column 3
# Board State: [4, 2, 2, 3, 2, 1, 6, 3]
# Step 72: Temp=48.50, Conflicts=12, Conflict Change=1, Moving Queen at Row 7 to Column 7
# Board State: [4, 2, 2, 3, 2, 1, 6, 3]
# Step 73: Temp=48.01, Conflicts=11, Conflict Change=-1, Moving Queen at Row 3 to Column 1
# Board State: [4, 2, 2, 1, 2, 1, 6, 3]
# Step 74: Temp=47.53, Conflicts=12, Conflict Change=1, Moving Queen at Row 4 to Column 0
# Board State: [4, 2, 2, 1, 0, 1, 6, 3]
# Step 75: Temp=47.06, Conflicts=12, Conflict Change=0, Moving Queen at Row 1 to Column 4
# Board State: [4, 4, 2, 1, 0, 1, 6, 3]
# Step 76: Temp=46.59, Conflicts=9, Conflict Change=-3, Moving Queen at Row 2 to Column 5
# Board State: [4, 4, 5, 1, 0, 1, 6, 3]
# Step 77: Temp=46.12, Conflicts=7, Conflict Change=-2, Moving Queen at Row 4 to Column 2
# Board State: [4, 4, 5, 1, 2, 1, 6, 3]
# Step 78: Temp=45.66, Conflicts=5, Conflict Change=-2, Moving Queen at Row 5 to Column 6
# Board State: [4, 4, 5, 1, 2, 6, 6, 3]
# Step 79: Temp=45.20, Conflicts=5, Conflict Change=0, Moving Queen at Row 5 to Column 7
# Board State: [4, 4, 5, 1, 2, 7, 6, 3]
# Step 80: Temp=44.75, Conflicts=4, Conflict Change=-1, Moving Queen at Row 1 to Column 2
# Board State: [4, 2, 5, 1, 2, 7, 6, 3]
# Step 81: Temp=44.30, Conflicts=5, Conflict Change=1, Moving Queen at Row 7 to Column 4
# Board State: [4, 2, 5, 1, 2, 7, 6, 4]
# Step 82: Temp=43.86, Conflicts=6, Conflict Change=1, Moving Queen at Row 7 to Column 2
# Board State: [4, 2, 5, 1, 2, 7, 6, 2]
# Step 83: Temp=43.42, Conflicts=12, Conflict Change=6, Moving Queen at Row 2 to Column 2
# Board State: [4, 2, 2, 1, 2, 7, 6, 2]
# Step 84: Temp=42.99, Conflicts=11, Conflict Change=-1, Moving Queen at Row 0 to Column 3
# Board State: [3, 2, 2, 1, 2, 7, 6, 2]
# Step 85: Temp=42.56, Conflicts=9, Conflict Change=-2, Moving Queen at Row 4 to Column 6
# Board State: [3, 2, 2, 1, 6, 7, 6, 2]
# Step 86: Temp=42.13, Conflicts=6, Conflict Change=-3, Moving Queen at Row 6 to Column 5
# Board State: [3, 2, 2, 1, 6, 7, 5, 2]
# Step 87: Temp=41.71, Conflicts=8, Conflict Change=2, Moving Queen at Row 4 to Column 5
# Board State: [3, 2, 2, 1, 5, 7, 5, 2]
# Step 88: Temp=41.29, Conflicts=11, Conflict Change=3, Moving Queen at Row 5 to Column 2
# Board State: [3, 2, 2, 1, 5, 2, 5, 2]
# Step 89: Temp=40.88, Conflicts=12, Conflict Change=1, Moving Queen at Row 0 to Column 5
# Board State: [5, 2, 2, 1, 5, 2, 5, 2]
# Step 90: Temp=40.47, Conflicts=9, Conflict Change=-3, Moving Queen at Row 4 to Column 7
# Board State: [5, 2, 2, 1, 7, 2, 5, 2]
# Step 91: Temp=40.07, Conflicts=9, Conflict Change=0, Moving Queen at Row 6 to Column 3
# Board State: [5, 2, 2, 1, 7, 2, 3, 2]
# Step 92: Temp=39.67, Conflicts=8, Conflict Change=-1, Moving Queen at Row 7 to Column 4
# Board State: [5, 2, 2, 1, 7, 2, 3, 4]
# Step 93: Temp=39.27, Conflicts=6, Conflict Change=-2, Moving Queen at Row 5 to Column 4
# Board State: [5, 2, 2, 1, 7, 4, 3, 4]
# Step 94: Temp=38.88, Conflicts=6, Conflict Change=0, Moving Queen at Row 5 to Column 3
# Board State: [5, 2, 2, 1, 7, 3, 3, 4]
# Step 95: Temp=38.49, Conflicts=7, Conflict Change=1, Moving Queen at Row 0 to Column 0
# Board State: [0, 2, 2, 1, 7, 3, 3, 4]
# Step 96: Temp=38.10, Conflicts=9, Conflict Change=2, Moving Queen at Row 3 to Column 3
# Board State: [0, 2, 2, 3, 7, 3, 3, 4]
# Step 97: Temp=37.72, Conflicts=8, Conflict Change=-1, Moving Queen at Row 5 to Column 0
# Board State: [0, 2, 2, 3, 7, 0, 3, 4]
# Step 98: Temp=37.35, Conflicts=6, Conflict Change=-2, Moving Queen at Row 2 to Column 5
# Board State: [0, 2, 5, 3, 7, 0, 3, 4]
# Step 99: Temp=36.97, Conflicts=6, Conflict Change=0, Moving Queen at Row 0 to Column 5
# Board State: [5, 2, 5, 3, 7, 0, 3, 4]
# Step 100: Temp=36.60, Conflicts=9, Conflict Change=3, Moving Queen at Row 1 to Column 5
# Board State: [5, 5, 5, 3, 7, 0, 3, 4]
# Step 101: Temp=36.24, Conflicts=7, Conflict Change=-2, Moving Queen at Row 7 to Column 6
# Board State: [5, 5, 5, 3, 7, 0, 3, 6]
# Step 102: Temp=35.87, Conflicts=9, Conflict Change=2, Moving Queen at Row 7 to Column 3
# Board State: [5, 5, 5, 3, 7, 0, 3, 3]
# Step 103: Temp=35.52, Conflicts=7, Conflict Change=-2, Moving Queen at Row 0 to Column 4
# Board State: [4, 5, 5, 3, 7, 0, 3, 3]
# Step 104: Temp=35.16, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 0
# Board State: [0, 5, 5, 3, 7, 0, 3, 3]
# Step 105: Temp=34.81, Conflicts=7, Conflict Change=-1, Moving Queen at Row 3 to Column 0
# Board State: [0, 5, 5, 0, 7, 0, 3, 3]
# Step 106: Temp=34.46, Conflicts=8, Conflict Change=1, Moving Queen at Row 2 to Column 3
# Board State: [0, 5, 3, 0, 7, 0, 3, 3]
# Step 107: Temp=34.12, Conflicts=7, Conflict Change=-1, Moving Queen at Row 3 to Column 2
# Board State: [0, 5, 3, 2, 7, 0, 3, 3]
# Step 108: Temp=33.78, Conflicts=8, Conflict Change=1, Moving Queen at Row 4 to Column 6
# Board State: [0, 5, 3, 2, 6, 0, 3, 3]
# Step 109: Temp=33.44, Conflicts=7, Conflict Change=-1, Moving Queen at Row 7 to Column 6
# Board State: [0, 5, 3, 2, 6, 0, 3, 6]
# Step 110: Temp=33.10, Conflicts=10, Conflict Change=3, Moving Queen at Row 4 to Column 3
# Board State: [0, 5, 3, 2, 3, 0, 3, 6]
# Step 111: Temp=32.77, Conflicts=8, Conflict Change=-2, Moving Queen at Row 4 to Column 2
# Board State: [0, 5, 3, 2, 2, 0, 3, 6]
# Step 112: Temp=32.44, Conflicts=8, Conflict Change=0, Moving Queen at Row 0 to Column 4
# Board State: [4, 5, 3, 2, 2, 0, 3, 6]
# Step 113: Temp=32.12, Conflicts=6, Conflict Change=-2, Moving Queen at Row 2 to Column 7
# Board State: [4, 5, 7, 2, 2, 0, 3, 6]
# Step 114: Temp=31.80, Conflicts=7, Conflict Change=1, Moving Queen at Row 5 to Column 1
# Board State: [4, 5, 7, 2, 2, 1, 3, 6]
# Step 115: Temp=31.48, Conflicts=7, Conflict Change=0, Moving Queen at Row 2 to Column 0
# Board State: [4, 5, 0, 2, 2, 1, 3, 6]
# Step 116: Temp=31.17, Conflicts=4, Conflict Change=-3, Moving Queen at Row 4 to Column 4
# Board State: [4, 5, 0, 2, 4, 1, 3, 6]
# Step 117: Temp=30.85, Conflicts=5, Conflict Change=1, Moving Queen at Row 4 to Column 5
# Board State: [4, 5, 0, 2, 5, 1, 3, 6]
# Step 118: Temp=30.55, Conflicts=2, Conflict Change=-3, Moving Queen at Row 1 to Column 7
# Board State: [4, 7, 0, 2, 5, 1, 3, 6]
# Step 119: Temp=30.24, Conflicts=4, Conflict Change=2, Moving Queen at Row 6 to Column 7
# Board State: [4, 7, 0, 2, 5, 1, 7, 6]
# Step 120: Temp=29.94, Conflicts=4, Conflict Change=2, Moving Queen at Row 0 to Column 5
# Board State: [4, 7, 0, 2, 5, 1, 7, 6]
# Step 121: Temp=29.64, Conflicts=5, Conflict Change=1, Moving Queen at Row 1 to Column 4
# Board State: [4, 4, 0, 2, 5, 1, 7, 6]
# Step 122: Temp=29.34, Conflicts=7, Conflict Change=2, Moving Queen at Row 4 to Column 2
# Board State: [4, 4, 0, 2, 2, 1, 7, 6]
# Step 123: Temp=29.05, Conflicts=6, Conflict Change=-1, Moving Queen at Row 1 to Column 3
# Board State: [4, 3, 0, 2, 2, 1, 7, 6]
# Step 124: Temp=28.76, Conflicts=6, Conflict Change=0, Moving Queen at Row 3 to Column 4
# Board State: [4, 3, 0, 4, 2, 1, 7, 6]
# Step 125: Temp=28.47, Conflicts=5, Conflict Change=-1, Moving Queen at Row 3 to Column 5
# Board State: [4, 3, 0, 5, 2, 1, 7, 6]
# Step 126: Temp=28.19, Conflicts=5, Conflict Change=0, Moving Queen at Row 0 to Column 5
# Board State: [5, 3, 0, 5, 2, 1, 7, 6]
# Step 127: Temp=27.90, Conflicts=6, Conflict Change=1, Moving Queen at Row 2 to Column 6
# Board State: [5, 3, 6, 5, 2, 1, 7, 6]
# Step 128: Temp=27.63, Conflicts=8, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [5, 3, 4, 5, 2, 1, 7, 6]
# Step 129: Temp=27.35, Conflicts=9, Conflict Change=1, Moving Queen at Row 6 to Column 4
# Board State: [5, 3, 4, 5, 2, 1, 4, 6]
# Step 130: Temp=27.08, Conflicts=9, Conflict Change=0, Moving Queen at Row 0 to Column 3
# Board State: [3, 3, 4, 5, 2, 1, 4, 6]
# Step 131: Temp=26.80, Conflicts=11, Conflict Change=2, Moving Queen at Row 7 to Column 4
# Board State: [3, 3, 4, 5, 2, 1, 4, 4]
# Step 132: Temp=26.54, Conflicts=10, Conflict Change=-1, Moving Queen at Row 1 to Column 2
# Board State: [3, 2, 4, 5, 2, 1, 4, 4]
# Step 133: Temp=26.27, Conflicts=8, Conflict Change=-2, Moving Queen at Row 4 to Column 1
# Board State: [3, 2, 4, 5, 1, 1, 4, 4]
# Step 134: Temp=26.01, Conflicts=7, Conflict Change=-1, Moving Queen at Row 0 to Column 7
# Board State: [7, 2, 4, 5, 1, 1, 4, 4]
# Step 135: Temp=25.75, Conflicts=8, Conflict Change=1, Moving Queen at Row 1 to Column 6
# Board State: [7, 6, 4, 5, 1, 1, 4, 4]
# Step 136: Temp=25.49, Conflicts=8, Conflict Change=0, Moving Queen at Row 5 to Column 3
# Board State: [7, 6, 4, 5, 1, 3, 4, 4]
# Step 137: Temp=25.24, Conflicts=5, Conflict Change=-3, Moving Queen at Row 7 to Column 2
# Board State: [7, 6, 4, 5, 1, 3, 4, 2]
# Step 138: Temp=24.98, Conflicts=4, Conflict Change=-1, Moving Queen at Row 6 to Column 7
# Board State: [7, 6, 4, 5, 1, 3, 7, 2]
# Step 139: Temp=24.73, Conflicts=5, Conflict Change=1, Moving Queen at Row 7 to Column 3
# Board State: [7, 6, 4, 5, 1, 3, 7, 3]
# Step 140: Temp=24.49, Conflicts=5, Conflict Change=0, Moving Queen at Row 1 to Column 1
# Board State: [7, 1, 4, 5, 1, 3, 7, 3]
# Step 141: Temp=24.24, Conflicts=6, Conflict Change=1, Moving Queen at Row 5 to Column 5
# Board State: [7, 1, 4, 5, 1, 5, 7, 3]
# Step 142: Temp=24.00, Conflicts=7, Conflict Change=1, Moving Queen at Row 7 to Column 5
# Board State: [7, 1, 4, 5, 1, 5, 7, 5]
# Step 143: Temp=23.76, Conflicts=7, Conflict Change=0, Moving Queen at Row 0 to Column 6
# Board State: [6, 1, 4, 5, 1, 5, 7, 5]
# Step 144: Temp=23.52, Conflicts=6, Conflict Change=-1, Moving Queen at Row 4 to Column 0
# Board State: [6, 1, 4, 5, 0, 5, 7, 5]
# Step 145: Temp=23.29, Conflicts=8, Conflict Change=2, Moving Queen at Row 1 to Column 7
# Board State: [6, 7, 4, 5, 0, 5, 7, 5]
# Step 146: Temp=23.05, Conflicts=7, Conflict Change=-1, Moving Queen at Row 7 to Column 4
# Board State: [6, 7, 4, 5, 0, 5, 7, 4]
# Step 147: Temp=22.82, Conflicts=6, Conflict Change=-1, Moving Queen at Row 3 to Column 0
# Board State: [6, 7, 4, 0, 0, 5, 7, 4]
# Step 148: Temp=22.59, Conflicts=6, Conflict Change=0, Moving Queen at Row 1 to Column 2
# Board State: [6, 2, 4, 0, 0, 5, 7, 4]
# Step 149: Temp=22.37, Conflicts=6, Conflict Change=0, Moving Queen at Row 2 to Column 1
# Board State: [6, 2, 1, 0, 0, 5, 7, 4]
# Step 150: Temp=22.15, Conflicts=6, Conflict Change=3, Moving Queen at Row 5 to Column 2
# Board State: [6, 2, 1, 0, 0, 5, 7, 4]
# Step 151: Temp=21.92, Conflicts=6, Conflict Change=0, Moving Queen at Row 2 to Column 3
# Board State: [6, 2, 3, 0, 0, 5, 7, 4]
# Step 152: Temp=21.70, Conflicts=7, Conflict Change=1, Moving Queen at Row 0 to Column 2
# Board State: [2, 2, 3, 0, 0, 5, 7, 4]
# Step 153: Temp=21.49, Conflicts=7, Conflict Change=0, Moving Queen at Row 4 to Column 3
# Board State: [2, 2, 3, 0, 3, 5, 7, 4]
# Step 154: Temp=21.27, Conflicts=5, Conflict Change=-2, Moving Queen at Row 3 to Column 6
# Board State: [2, 2, 3, 6, 3, 5, 7, 4]
# Step 155: Temp=21.06, Conflicts=6, Conflict Change=1, Moving Queen at Row 4 to Column 4
# Board State: [2, 2, 3, 6, 4, 5, 7, 4]
# Step 156: Temp=20.85, Conflicts=6, Conflict Change=0, Moving Queen at Row 1 to Column 1
# Board State: [2, 1, 3, 6, 4, 5, 7, 4]
# Step 157: Temp=20.64, Conflicts=7, Conflict Change=1, Moving Queen at Row 7 to Column 2
# Board State: [2, 1, 3, 6, 4, 5, 7, 2]
# Step 158: Temp=20.43, Conflicts=8, Conflict Change=1, Moving Queen at Row 5 to Column 6
# Board State: [2, 1, 3, 6, 4, 6, 7, 2]
# Step 159: Temp=20.23, Conflicts=7, Conflict Change=-1, Moving Queen at Row 4 to Column 0
# Board State: [2, 1, 3, 6, 0, 6, 7, 2]
# Step 160: Temp=20.03, Conflicts=8, Conflict Change=1, Moving Queen at Row 4 to Column 3
# Board State: [2, 1, 3, 6, 3, 6, 7, 2]
# Step 161: Temp=19.83, Conflicts=9, Conflict Change=1, Moving Queen at Row 4 to Column 1
# Board State: [2, 1, 3, 6, 1, 6, 7, 2]
# Step 162: Temp=19.63, Conflicts=8, Conflict Change=-1, Moving Queen at Row 4 to Column 3
# Board State: [2, 1, 3, 6, 3, 6, 7, 2]
# Step 163: Temp=19.43, Conflicts=6, Conflict Change=-2, Moving Queen at Row 5 to Column 1
# Board State: [2, 1, 3, 6, 3, 1, 7, 2]
# Step 164: Temp=19.24, Conflicts=6, Conflict Change=0, Moving Queen at Row 0 to Column 7
# Board State: [7, 1, 3, 6, 3, 1, 7, 2]
# Step 165: Temp=19.05, Conflicts=5, Conflict Change=-1, Moving Queen at Row 7 to Column 4
# Board State: [7, 1, 3, 6, 3, 1, 7, 4]
# Step 166: Temp=18.86, Conflicts=4, Conflict Change=-1, Moving Queen at Row 6 to Column 4
# Board State: [7, 1, 3, 6, 3, 1, 4, 4]
# Step 167: Temp=18.67, Conflicts=4, Conflict Change=0, Moving Queen at Row 0 to Column 2
# Board State: [2, 1, 3, 6, 3, 1, 4, 4]
# Step 168: Temp=18.48, Conflicts=5, Conflict Change=1, Moving Queen at Row 5 to Column 5
# Board State: [2, 1, 3, 6, 3, 5, 4, 4]
# Step 169: Temp=18.30, Conflicts=5, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [2, 1, 3, 6, 3, 5, 4, 4]
# Step 170: Temp=18.11, Conflicts=7, Conflict Change=2, Moving Queen at Row 3 to Column 1
# Board State: [2, 1, 3, 1, 3, 5, 4, 4]
# Step 171: Temp=17.93, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 5
# Board State: [5, 1, 3, 1, 3, 5, 4, 4]
# Step 172: Temp=17.75, Conflicts=7, Conflict Change=-1, Moving Queen at Row 1 to Column 2
# Board State: [5, 2, 3, 1, 3, 5, 4, 4]
# Step 173: Temp=17.57, Conflicts=8, Conflict Change=1, Moving Queen at Row 6 to Column 5
# Board State: [5, 2, 3, 1, 3, 5, 5, 4]
# Step 174: Temp=17.40, Conflicts=4, Conflict Change=-4, Moving Queen at Row 6 to Column 0
# Board State: [5, 2, 3, 1, 3, 5, 0, 4]
# Step 175: Temp=17.22, Conflicts=4, Conflict Change=0, Moving Queen at Row 2 to Column 1
# Board State: [5, 2, 1, 1, 3, 5, 0, 4]
# Step 176: Temp=17.05, Conflicts=5, Conflict Change=1, Moving Queen at Row 6 to Column 6
# Board State: [5, 2, 1, 1, 3, 5, 6, 4]
# Step 177: Temp=16.88, Conflicts=4, Conflict Change=-1, Moving Queen at Row 5 to Column 0
# Board State: [5, 2, 1, 1, 3, 0, 6, 4]
# Step 178: Temp=16.71, Conflicts=4, Conflict Change=0, Moving Queen at Row 3 to Column 5
# Board State: [5, 2, 1, 5, 3, 0, 6, 4]
# Step 179: Temp=16.55, Conflicts=6, Conflict Change=2, Moving Queen at Row 4 to Column 4
# Board State: [5, 2, 1, 5, 4, 0, 6, 4]
# Step 180: Temp=16.38, Conflicts=9, Conflict Change=3, Moving Queen at Row 6 to Column 5
# Board State: [5, 2, 1, 5, 4, 0, 5, 4]
# Step 181: Temp=16.22, Conflicts=6, Conflict Change=-3, Moving Queen at Row 0 to Column 7
# Board State: [7, 2, 1, 5, 4, 0, 5, 4]
# Step 182: Temp=16.05, Conflicts=7, Conflict Change=1, Moving Queen at Row 5 to Column 1
# Board State: [7, 2, 1, 5, 4, 1, 5, 4]
# Step 183: Temp=15.89, Conflicts=7, Conflict Change=0, Moving Queen at Row 3 to Column 1
# Board State: [7, 2, 1, 1, 4, 1, 5, 4]
# Step 184: Temp=15.74, Conflicts=7, Conflict Change=0, Moving Queen at Row 7 to Column 6
# Board State: [7, 2, 1, 1, 4, 1, 5, 6]
# Step 185: Temp=15.58, Conflicts=7, Conflict Change=0, Moving Queen at Row 3 to Column 0
# Board State: [7, 2, 1, 0, 4, 1, 5, 6]
# Step 186: Temp=15.42, Conflicts=8, Conflict Change=1, Moving Queen at Row 7 to Column 4
# Board State: [7, 2, 1, 0, 4, 1, 5, 4]
# Step 187: Temp=15.27, Conflicts=9, Conflict Change=1, Moving Queen at Row 6 to Column 1
# Board State: [7, 2, 1, 0, 4, 1, 1, 4]
# Step 188: Temp=15.12, Conflicts=9, Conflict Change=0, Moving Queen at Row 7 to Column 2
# Board State: [7, 2, 1, 0, 4, 1, 1, 2]
# Step 189: Temp=14.96, Conflicts=8, Conflict Change=-1, Moving Queen at Row 3 to Column 5
# Board State: [7, 2, 1, 5, 4, 1, 1, 2]
# Step 190: Temp=14.81, Conflicts=7, Conflict Change=-1, Moving Queen at Row 7 to Column 5
# Board State: [7, 2, 1, 5, 4, 1, 1, 5]
# Step 191: Temp=14.67, Conflicts=7, Conflict Change=0, Moving Queen at Row 6 to Column 5
# Board State: [7, 2, 1, 5, 4, 1, 5, 5]
# Step 192: Temp=14.52, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 6
# Board State: [6, 2, 1, 5, 4, 1, 5, 5]
# Step 193: Temp=14.37, Conflicts=7, Conflict Change=-1, Moving Queen at Row 0 to Column 7
# Board State: [7, 2, 1, 5, 4, 1, 5, 5]
# Step 194: Temp=14.23, Conflicts=6, Conflict Change=-1, Moving Queen at Row 6 to Column 4
# Board State: [7, 2, 1, 5, 4, 1, 4, 5]
# Step 195: Temp=14.09, Conflicts=6, Conflict Change=0, Moving Queen at Row 3 to Column 7
# Board State: [7, 2, 1, 7, 4, 1, 4, 5]
# Step 196: Temp=13.95, Conflicts=7, Conflict Change=1, Moving Queen at Row 4 to Column 7
# Board State: [7, 2, 1, 7, 7, 1, 4, 5]
# Step 197: Temp=13.81, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 3
# Board State: [3, 2, 1, 7, 7, 1, 4, 5]
# Step 198: Temp=13.67, Conflicts=6, Conflict Change=-2, Moving Queen at Row 2 to Column 2
# Board State: [3, 2, 2, 7, 7, 1, 4, 5]
# Step 199: Temp=13.53, Conflicts=6, Conflict Change=0, Moving Queen at Row 1 to Column 7
# Board State: [3, 7, 2, 7, 7, 1, 4, 5]
# Step 200: Temp=13.40, Conflicts=5, Conflict Change=-1, Moving Queen at Row 3 to Column 5
# Board State: [3, 7, 2, 5, 7, 1, 4, 5]
# Step 201: Temp=13.26, Conflicts=3, Conflict Change=-2, Moving Queen at Row 1 to Column 6
# Board State: [3, 6, 2, 5, 7, 1, 4, 5]
# Step 202: Temp=13.13, Conflicts=3, Conflict Change=2, Moving Queen at Row 2 to Column 7
# Board State: [3, 6, 2, 5, 7, 1, 4, 5]
# Step 203: Temp=13.00, Conflicts=3, Conflict Change=0, Moving Queen at Row 7 to Column 4
# Board State: [3, 6, 2, 5, 7, 1, 4, 4]
# Step 204: Temp=12.87, Conflicts=3, Conflict Change=0, Moving Queen at Row 5 to Column 0
# Board State: [3, 6, 2, 5, 7, 0, 4, 4]
# Step 205: Temp=12.74, Conflicts=5, Conflict Change=2, Moving Queen at Row 3 to Column 2
# Board State: [3, 6, 2, 2, 7, 0, 4, 4]
# Step 206: Temp=12.61, Conflicts=5, Conflict Change=2, Moving Queen at Row 1 to Column 0
# Board State: [3, 6, 2, 2, 7, 0, 4, 4]
# Step 207: Temp=12.49, Conflicts=6, Conflict Change=1, Moving Queen at Row 2 to Column 0
# Board State: [3, 6, 0, 2, 7, 0, 4, 4]
# Step 208: Temp=12.36, Conflicts=5, Conflict Change=-1, Moving Queen at Row 6 to Column 7
# Board State: [3, 6, 0, 2, 7, 0, 7, 4]
# Step 209: Temp=12.24, Conflicts=3, Conflict Change=-2, Moving Queen at Row 4 to Column 6
# Board State: [3, 6, 0, 2, 6, 0, 7, 4]
# Step 210: Temp=12.12, Conflicts=5, Conflict Change=2, Moving Queen at Row 6 to Column 0
# Board State: [3, 6, 0, 2, 6, 0, 0, 4]
# Step 211: Temp=12.00, Conflicts=7, Conflict Change=2, Moving Queen at Row 3 to Column 6
# Board State: [3, 6, 0, 6, 6, 0, 0, 4]
# Step 212: Temp=11.88, Conflicts=6, Conflict Change=-1, Moving Queen at Row 2 to Column 1
# Board State: [3, 6, 1, 6, 6, 0, 0, 4]
# Step 213: Temp=11.76, Conflicts=4, Conflict Change=-2, Moving Queen at Row 3 to Column 1
# Board State: [3, 6, 1, 1, 6, 0, 0, 4]
# Step 214: Temp=11.64, Conflicts=3, Conflict Change=-1, Moving Queen at Row 4 to Column 5
# Board State: [3, 6, 1, 1, 5, 0, 0, 4]
# Step 215: Temp=11.52, Conflicts=3, Conflict Change=2, Moving Queen at Row 5 to Column 6
# Board State: [3, 6, 1, 1, 5, 0, 0, 4]
# Step 216: Temp=11.41, Conflicts=2, Conflict Change=-1, Moving Queen at Row 2 to Column 6
# Board State: [3, 6, 6, 1, 5, 0, 0, 4]
# Step 217: Temp=11.29, Conflicts=2, Conflict Change=1, Moving Queen at Row 2 to Column 7
# Board State: [3, 6, 6, 1, 5, 0, 0, 4]
# Step 218: Temp=11.18, Conflicts=4, Conflict Change=2, Moving Queen at Row 0 to Column 1
# Board State: [1, 6, 6, 1, 5, 0, 0, 4]
# Step 219: Temp=11.07, Conflicts=4, Conflict Change=2, Moving Queen at Row 7 to Column 5
# Board State: [1, 6, 6, 1, 5, 0, 0, 4]
# Step 220: Temp=10.96, Conflicts=4, Conflict Change=0, Moving Queen at Row 1 to Column 3
# Board State: [1, 3, 6, 1, 5, 0, 0, 4]
# Step 221: Temp=10.85, Conflicts=3, Conflict Change=-1, Moving Queen at Row 3 to Column 2
# Board State: [1, 3, 6, 2, 5, 0, 0, 4]
# Step 222: Temp=10.74, Conflicts=3, Conflict Change=0, Moving Queen at Row 4 to Column 7
# Board State: [1, 3, 6, 2, 7, 0, 0, 4]
# Step 223: Temp=10.63, Conflicts=5, Conflict Change=2, Moving Queen at Row 0 to Column 2
# Board State: [2, 3, 6, 2, 7, 0, 0, 4]
# Step 224: Temp=10.53, Conflicts=3, Conflict Change=-2, Moving Queen at Row 0 to Column 1
# Board State: [1, 3, 6, 2, 7, 0, 0, 4]
# Step 225: Temp=10.42, Conflicts=5, Conflict Change=2, Moving Queen at Row 2 to Column 2
# Board State: [1, 3, 2, 2, 7, 0, 0, 4]
# Step 226: Temp=10.32, Conflicts=4, Conflict Change=-1, Moving Queen at Row 3 to Column 5
# Board State: [1, 3, 2, 5, 7, 0, 0, 4]
# Step 227: Temp=10.21, Conflicts=5, Conflict Change=1, Moving Queen at Row 7 to Column 2
# Board State: [1, 3, 2, 5, 7, 0, 0, 2]
# Step 228: Temp=10.11, Conflicts=7, Conflict Change=2, Moving Queen at Row 6 to Column 1
# Board State: [1, 3, 2, 5, 7, 0, 1, 2]
# Step 229: Temp=10.01, Conflicts=7, Conflict Change=0, Moving Queen at Row 6 to Column 2
# Board State: [1, 3, 2, 5, 7, 0, 2, 2]
# Step 230: Temp=9.91, Conflicts=7, Conflict Change=0, Moving Queen at Row 7 to Column 1
# Board State: [1, 3, 2, 5, 7, 0, 2, 1]
# Step 231: Temp=9.81, Conflicts=5, Conflict Change=-2, Moving Queen at Row 7 to Column 4
# Board State: [1, 3, 2, 5, 7, 0, 2, 4]
# Step 232: Temp=9.71, Conflicts=4, Conflict Change=-1, Moving Queen at Row 1 to Column 5
# Board State: [1, 5, 2, 5, 7, 0, 2, 4]
# Step 233: Temp=9.62, Conflicts=3, Conflict Change=-1, Moving Queen at Row 7 to Column 6
# Board State: [1, 5, 2, 5, 7, 0, 2, 6]
# Step 234: Temp=9.52, Conflicts=5, Conflict Change=2, Moving Queen at Row 7 to Column 5
# Board State: [1, 5, 2, 5, 7, 0, 2, 5]
# Step 235: Temp=9.42, Conflicts=7, Conflict Change=2, Moving Queen at Row 6 to Column 5
# Board State: [1, 5, 2, 5, 7, 0, 5, 5]
# Step 236: Temp=9.33, Conflicts=6, Conflict Change=-1, Moving Queen at Row 3 to Column 7
# Board State: [1, 5, 2, 7, 7, 0, 5, 5]
# Step 237: Temp=9.24, Conflicts=5, Conflict Change=-1, Moving Queen at Row 3 to Column 6
# Board State: [1, 5, 2, 6, 7, 0, 5, 5]
# Step 238: Temp=9.14, Conflicts=3, Conflict Change=-2, Moving Queen at Row 7 to Column 3
# Board State: [1, 5, 2, 6, 7, 0, 5, 3]
# Step 239: Temp=9.05, Conflicts=5, Conflict Change=2, Moving Queen at Row 2 to Column 1
# Board State: [1, 5, 1, 6, 7, 0, 5, 3]
# Step 240: Temp=8.96, Conflicts=5, Conflict Change=3, Moving Queen at Row 0 to Column 3
# Board State: [1, 5, 1, 6, 7, 0, 5, 3]
# Step 241: Temp=8.87, Conflicts=6, Conflict Change=1, Moving Queen at Row 1 to Column 2
# Board State: [1, 2, 1, 6, 7, 0, 5, 3]
# Step 242: Temp=8.78, Conflicts=5, Conflict Change=-1, Moving Queen at Row 0 to Column 7
# Board State: [7, 2, 1, 6, 7, 0, 5, 3]
# Step 243: Temp=8.70, Conflicts=6, Conflict Change=1, Moving Queen at Row 1 to Column 7
# Board State: [7, 7, 1, 6, 7, 0, 5, 3]
# Step 244: Temp=8.61, Conflicts=5, Conflict Change=-1, Moving Queen at Row 1 to Column 5
# Board State: [7, 5, 1, 6, 7, 0, 5, 3]
# Step 245: Temp=8.52, Conflicts=6, Conflict Change=1, Moving Queen at Row 5 to Column 3
# Board State: [7, 5, 1, 6, 7, 3, 5, 3]
# Step 246: Temp=8.44, Conflicts=6, Conflict Change=0, Moving Queen at Row 4 to Column 5
# Board State: [7, 5, 1, 6, 5, 3, 5, 3]
# Step 247: Temp=8.35, Conflicts=5, Conflict Change=-1, Moving Queen at Row 1 to Column 4
# Board State: [7, 4, 1, 6, 5, 3, 5, 3]
# Step 248: Temp=8.27, Conflicts=5, Conflict Change=0, Moving Queen at Row 3 to Column 7
# Board State: [7, 4, 1, 7, 5, 3, 5, 3]
# Step 249: Temp=8.19, Conflicts=5, Conflict Change=1, Moving Queen at Row 4 to Column 1
# Board State: [7, 4, 1, 7, 5, 3, 5, 3]
# Step 250: Temp=8.11, Conflicts=5, Conflict Change=0, Moving Queen at Row 3 to Column 6
# Board State: [7, 4, 1, 6, 5, 3, 5, 3]
# Step 251: Temp=8.02, Conflicts=6, Conflict Change=1, Moving Queen at Row 7 to Column 2
# Board State: [7, 4, 1, 6, 5, 3, 5, 2]
# Step 252: Temp=7.94, Conflicts=12, Conflict Change=6, Moving Queen at Row 5 to Column 4
# Board State: [7, 4, 1, 6, 5, 4, 5, 2]
# Step 253: Temp=7.87, Conflicts=11, Conflict Change=-1, Moving Queen at Row 2 to Column 2
# Board State: [7, 4, 2, 6, 5, 4, 5, 2]
# Step 254: Temp=7.79, Conflicts=6, Conflict Change=-5, Moving Queen at Row 5 to Column 1
# Board State: [7, 4, 2, 6, 5, 1, 5, 2]
# Step 255: Temp=7.71, Conflicts=4, Conflict Change=-2, Moving Queen at Row 4 to Column 6
# Board State: [7, 4, 2, 6, 6, 1, 5, 2]
# Step 256: Temp=7.63, Conflicts=3, Conflict Change=-1, Moving Queen at Row 7 to Column 0
# Board State: [7, 4, 2, 6, 6, 1, 5, 0]
# Step 257: Temp=7.56, Conflicts=4, Conflict Change=1, Moving Queen at Row 1 to Column 3
# Board State: [7, 3, 2, 6, 6, 1, 5, 0]
# Step 258: Temp=7.48, Conflicts=4, Conflict Change=3, Moving Queen at Row 5 to Column 5
# Board State: [7, 3, 2, 6, 6, 1, 5, 0]
# Step 259: Temp=7.40, Conflicts=6, Conflict Change=2, Moving Queen at Row 7 to Column 6
# Board State: [7, 3, 2, 6, 6, 1, 5, 6]
# Step 260: Temp=7.33, Conflicts=8, Conflict Change=2, Moving Queen at Row 2 to Column 6
# Board State: [7, 3, 6, 6, 6, 1, 5, 6]
# Step 261: Temp=7.26, Conflicts=10, Conflict Change=2, Moving Queen at Row 1 to Column 5
# Board State: [7, 5, 6, 6, 6, 1, 5, 6]
# Step 262: Temp=7.18, Conflicts=9, Conflict Change=-1, Moving Queen at Row 1 to Column 0
# Board State: [7, 0, 6, 6, 6, 1, 5, 6]
# Step 263: Temp=7.11, Conflicts=9, Conflict Change=0, Moving Queen at Row 1 to Column 7
# Board State: [7, 7, 6, 6, 6, 1, 5, 6]
# Step 264: Temp=7.04, Conflicts=9, Conflict Change=0, Moving Queen at Row 1 to Column 0
# Board State: [7, 0, 6, 6, 6, 1, 5, 6]
# Step 265: Temp=6.97, Conflicts=8, Conflict Change=-1, Moving Queen at Row 6 to Column 4
# Board State: [7, 0, 6, 6, 6, 1, 4, 6]
# Step 266: Temp=6.90, Conflicts=9, Conflict Change=1, Moving Queen at Row 0 to Column 3
# Board State: [3, 0, 6, 6, 6, 1, 4, 6]
# Step 267: Temp=6.83, Conflicts=8, Conflict Change=-1, Moving Queen at Row 2 to Column 0
# Board State: [3, 0, 0, 6, 6, 1, 4, 6]
# Step 268: Temp=6.76, Conflicts=6, Conflict Change=-2, Moving Queen at Row 7 to Column 2
# Board State: [3, 0, 0, 6, 6, 1, 4, 2]
# Step 269: Temp=6.70, Conflicts=7, Conflict Change=1, Moving Queen at Row 1 to Column 6
# Board State: [3, 6, 0, 6, 6, 1, 4, 2]
# Step 270: Temp=6.63, Conflicts=8, Conflict Change=1, Moving Queen at Row 7 to Column 5
# Board State: [3, 6, 0, 6, 6, 1, 4, 5]
# Step 271: Temp=6.56, Conflicts=9, Conflict Change=1, Moving Queen at Row 7 to Column 6
# Board State: [3, 6, 0, 6, 6, 1, 4, 6]
# Step 272: Temp=6.50, Conflicts=8, Conflict Change=-1, Moving Queen at Row 1 to Column 0
# Board State: [3, 0, 0, 6, 6, 1, 4, 6]
# Step 273: Temp=6.43, Conflicts=9, Conflict Change=1, Moving Queen at Row 1 to Column 4
# Board State: [3, 4, 0, 6, 6, 1, 4, 6]
# Step 274: Temp=6.37, Conflicts=9, Conflict Change=3, Moving Queen at Row 5 to Column 3
# Board State: [3, 4, 0, 6, 6, 1, 4, 6]
# Step 275: Temp=6.30, Conflicts=9, Conflict Change=0, Moving Queen at Row 7 to Column 4
# Board State: [3, 4, 0, 6, 6, 1, 4, 4]
# Step 276: Temp=6.24, Conflicts=8, Conflict Change=-1, Moving Queen at Row 7 to Column 0
# Board State: [3, 4, 0, 6, 6, 1, 4, 0]
# Step 277: Temp=6.18, Conflicts=8, Conflict Change=0, Moving Queen at Row 0 to Column 2
# Board State: [2, 4, 0, 6, 6, 1, 4, 0]
# Step 278: Temp=6.12, Conflicts=9, Conflict Change=1, Moving Queen at Row 7 to Column 6
# Board State: [2, 4, 0, 6, 6, 1, 4, 6]
# Step 279: Temp=6.06, Conflicts=9, Conflict Change=1, Moving Queen at Row 1 to Column 6
# Board State: [2, 4, 0, 6, 6, 1, 4, 6]
# Step 280: Temp=6.00, Conflicts=7, Conflict Change=-2, Moving Queen at Row 4 to Column 1
# Board State: [2, 4, 0, 6, 1, 1, 4, 6]
# Step 281: Temp=5.94, Conflicts=5, Conflict Change=-2, Moving Queen at Row 1 to Column 3
# Board State: [2, 3, 0, 6, 1, 1, 4, 6]
# Step 282: Temp=5.88, Conflicts=4, Conflict Change=-1, Moving Queen at Row 2 to Column 7
# Board State: [2, 3, 7, 6, 1, 1, 4, 6]
# Step 283: Temp=5.82, Conflicts=5, Conflict Change=1, Moving Queen at Row 0 to Column 5
# Board State: [5, 3, 7, 6, 1, 1, 4, 6]
# Step 284: Temp=5.76, Conflicts=6, Conflict Change=1, Moving Queen at Row 7 to Column 1
# Board State: [5, 3, 7, 6, 1, 1, 4, 1]
# Step 285: Temp=5.70, Conflicts=6, Conflict Change=4, Moving Queen at Row 3 to Column 1
# Board State: [5, 3, 7, 6, 1, 1, 4, 1]
# Step 286: Temp=5.65, Conflicts=6, Conflict Change=4, Moving Queen at Row 6 to Column 3
# Board State: [5, 3, 7, 6, 1, 1, 4, 1]
# Step 287: Temp=5.59, Conflicts=7, Conflict Change=1, Moving Queen at Row 3 to Column 3
# Board State: [5, 3, 7, 3, 1, 1, 4, 1]
# Step 288: Temp=5.53, Conflicts=6, Conflict Change=-1, Moving Queen at Row 4 to Column 6
# Board State: [5, 3, 7, 3, 6, 1, 4, 1]
# Step 289: Temp=5.48, Conflicts=5, Conflict Change=-1, Moving Queen at Row 7 to Column 0
# Board State: [5, 3, 7, 3, 6, 1, 4, 0]
# Step 290: Temp=5.42, Conflicts=5, Conflict Change=0, Moving Queen at Row 1 to Column 1
# Board State: [5, 1, 7, 3, 6, 1, 4, 0]
# Step 291: Temp=5.37, Conflicts=5, Conflict Change=2, Moving Queen at Row 2 to Column 0
# Board State: [5, 1, 7, 3, 6, 1, 4, 0]
# Step 292: Temp=5.31, Conflicts=5, Conflict Change=0, Moving Queen at Row 5 to Column 7
# Board State: [5, 1, 7, 3, 6, 7, 4, 0]
# Step 293: Temp=5.26, Conflicts=6, Conflict Change=1, Moving Queen at Row 1 to Column 7
# Board State: [5, 7, 7, 3, 6, 7, 4, 0]
# Step 294: Temp=5.21, Conflicts=8, Conflict Change=2, Moving Queen at Row 6 to Column 6
# Board State: [5, 7, 7, 3, 6, 7, 6, 0]
# Step 295: Temp=5.16, Conflicts=11, Conflict Change=3, Moving Queen at Row 3 to Column 5
# Board State: [5, 7, 7, 5, 6, 7, 6, 0]
# Step 296: Temp=5.11, Conflicts=10, Conflict Change=-1, Moving Queen at Row 6 to Column 4
# Board State: [5, 7, 7, 5, 6, 7, 4, 0]
# Step 297: Temp=5.05, Conflicts=9, Conflict Change=-1, Moving Queen at Row 0 to Column 0
# Board State: [0, 7, 7, 5, 6, 7, 4, 0]
# Step 298: Temp=5.00, Conflicts=10, Conflict Change=1, Moving Queen at Row 2 to Column 0
# Board State: [0, 7, 0, 5, 6, 7, 4, 0]
# Step 299: Temp=4.95, Conflicts=8, Conflict Change=-2, Moving Queen at Row 0 to Column 1
# Board State: [1, 7, 0, 5, 6, 7, 4, 0]
# Step 300: Temp=4.90, Conflicts=6, Conflict Change=-2, Moving Queen at Row 2 to Column 2
# Board State: [1, 7, 2, 5, 6, 7, 4, 0]
# Step 301: Temp=4.86, Conflicts=6, Conflict Change=0, Moving Queen at Row 3 to Column 4
# Board State: [1, 7, 2, 4, 6, 7, 4, 0]
# Step 302: Temp=4.81, Conflicts=8, Conflict Change=2, Moving Queen at Row 2 to Column 5
# Board State: [1, 7, 5, 4, 6, 7, 4, 0]
# Step 303: Temp=4.76, Conflicts=9, Conflict Change=1, Moving Queen at Row 5 to Column 6
# Board State: [1, 7, 5, 4, 6, 6, 4, 0]
# Step 304: Temp=4.71, Conflicts=7, Conflict Change=-2, Moving Queen at Row 3 to Column 6
# Board State: [1, 7, 5, 6, 6, 6, 4, 0]
# Step 305: Temp=4.66, Conflicts=7, Conflict Change=2, Moving Queen at Row 0 to Column 7
# Board State: [1, 7, 5, 6, 6, 6, 4, 0]
# Step 306: Temp=4.62, Conflicts=7, Conflict Change=0, Moving Queen at Row 0 to Column 2
# Board State: [2, 7, 5, 6, 6, 6, 4, 0]
# Step 307: Temp=4.57, Conflicts=8, Conflict Change=1, Moving Queen at Row 7 to Column 3
# Board State: [2, 7, 5, 6, 6, 6, 4, 3]
# Step 308: Temp=4.53, Conflicts=7, Conflict Change=-1, Moving Queen at Row 6 to Column 1
# Board State: [2, 7, 5, 6, 6, 6, 1, 3]
# Step 309: Temp=4.48, Conflicts=7, Conflict Change=1, Moving Queen at Row 6 to Column 7
# Board State: [2, 7, 5, 6, 6, 6, 1, 3]
# Step 310: Temp=4.44, Conflicts=9, Conflict Change=2, Moving Queen at Row 2 to Column 6
# Board State: [2, 7, 6, 6, 6, 6, 1, 3]
# Step 311: Temp=4.39, Conflicts=5, Conflict Change=-4, Moving Queen at Row 4 to Column 1
# Board State: [2, 7, 6, 6, 1, 6, 1, 3]
# Step 312: Temp=4.35, Conflicts=9, Conflict Change=4, Moving Queen at Row 0 to Column 6
# Board State: [6, 7, 6, 6, 1, 6, 1, 3]
# Step 313: Temp=4.30, Conflicts=10, Conflict Change=1, Moving Queen at Row 5 to Column 1
# Board State: [6, 7, 6, 6, 1, 1, 1, 3]
# Step 314: Temp=4.26, Conflicts=10, Conflict Change=4, Moving Queen at Row 7 to Column 1
# Board State: [6, 7, 6, 6, 1, 1, 1, 3]
# Step 315: Temp=4.22, Conflicts=9, Conflict Change=-1, Moving Queen at Row 5 to Column 3
# Board State: [6, 7, 6, 6, 1, 3, 1, 3]
# Step 316: Temp=4.18, Conflicts=10, Conflict Change=1, Moving Queen at Row 7 to Column 2
# Board State: [6, 7, 6, 6, 1, 3, 1, 2]
# Step 317: Temp=4.13, Conflicts=8, Conflict Change=-2, Moving Queen at Row 0 to Column 2
# Board State: [2, 7, 6, 6, 1, 3, 1, 2]
# Step 318: Temp=4.09, Conflicts=8, Conflict Change=1, Moving Queen at Row 0 to Column 3
# Board State: [2, 7, 6, 6, 1, 3, 1, 2]
# Step 319: Temp=4.05, Conflicts=7, Conflict Change=-1, Moving Queen at Row 2 to Column 2
# Board State: [2, 7, 2, 6, 1, 3, 1, 2]
# Step 320: Temp=4.01, Conflicts=7, Conflict Change=0, Moving Queen at Row 3 to Column 0
# Board State: [2, 7, 2, 0, 1, 3, 1, 2]
# Step 321: Temp=3.97, Conflicts=6, Conflict Change=-1, Moving Queen at Row 6 to Column 0
# Board State: [2, 7, 2, 0, 1, 3, 0, 2]
# Step 322: Temp=3.93, Conflicts=6, Conflict Change=0, Moving Queen at Row 1 to Column 5
# Board State: [2, 5, 2, 0, 1, 3, 0, 2]
# Step 323: Temp=3.89, Conflicts=7, Conflict Change=1, Moving Queen at Row 5 to Column 7
# Board State: [2, 5, 2, 0, 1, 7, 0, 2]
# Step 324: Temp=3.85, Conflicts=7, Conflict Change=4, Moving Queen at Row 4 to Column 2
# Board State: [2, 5, 2, 0, 1, 7, 0, 2]
# Step 325: Temp=3.81, Conflicts=8, Conflict Change=1, Moving Queen at Row 4 to Column 6
# Board State: [2, 5, 2, 0, 6, 7, 0, 2]
# Step 326: Temp=3.78, Conflicts=6, Conflict Change=-2, Moving Queen at Row 2 to Column 3
# Board State: [2, 5, 3, 0, 6, 7, 0, 2]
# Step 327: Temp=3.74, Conflicts=8, Conflict Change=2, Moving Queen at Row 3 to Column 3
# Board State: [2, 5, 3, 3, 6, 7, 0, 2]
# Step 328: Temp=3.70, Conflicts=7, Conflict Change=-1, Moving Queen at Row 6 to Column 5
# Board State: [2, 5, 3, 3, 6, 7, 5, 2]
# Step 329: Temp=3.66, Conflicts=7, Conflict Change=0, Moving Queen at Row 1 to Column 1
# Board State: [2, 1, 3, 3, 6, 7, 5, 2]
# Step 330: Temp=3.63, Conflicts=7, Conflict Change=0, Moving Queen at Row 7 to Column 4
# Board State: [2, 1, 3, 3, 6, 7, 5, 4]
# Step 331: Temp=3.59, Conflicts=6, Conflict Change=-1, Moving Queen at Row 5 to Column 0
# Board State: [2, 1, 3, 3, 6, 0, 5, 4]
# Step 332: Temp=3.56, Conflicts=6, Conflict Change=2, Moving Queen at Row 7 to Column 3
# Board State: [2, 1, 3, 3, 6, 0, 5, 4]
# Step 333: Temp=3.52, Conflicts=9, Conflict Change=3, Moving Queen at Row 5 to Column 5
# Board State: [2, 1, 3, 3, 6, 5, 5, 4]
# Step 334: Temp=3.48, Conflicts=6, Conflict Change=-3, Moving Queen at Row 1 to Column 7
# Board State: [2, 7, 3, 3, 6, 5, 5, 4]
# Step 335: Temp=3.45, Conflicts=4, Conflict Change=-2, Moving Queen at Row 5 to Column 0
# Board State: [2, 7, 3, 3, 6, 0, 5, 4]
# Step 336: Temp=3.42, Conflicts=4, Conflict Change=1, Moving Queen at Row 7 to Column 7
# Board State: [2, 7, 3, 3, 6, 0, 5, 4]
# Step 337: Temp=3.38, Conflicts=6, Conflict Change=2, Moving Queen at Row 1 to Column 2
# Board State: [2, 2, 3, 3, 6, 0, 5, 4]
# Step 338: Temp=3.35, Conflicts=10, Conflict Change=4, Moving Queen at Row 3 to Column 2
# Board State: [2, 2, 3, 2, 6, 0, 5, 4]
# Step 339: Temp=3.31, Conflicts=9, Conflict Change=-1, Moving Queen at Row 5 to Column 3
# Board State: [2, 2, 3, 2, 6, 3, 5, 4]
# Step 340: Temp=3.28, Conflicts=9, Conflict Change=0, Moving Queen at Row 3 to Column 5
# Board State: [2, 2, 3, 5, 6, 3, 5, 4]
# Step 341: Temp=3.25, Conflicts=6, Conflict Change=-3, Moving Queen at Row 0 to Column 0
# Board State: [0, 2, 3, 5, 6, 3, 5, 4]
# Step 342: Temp=3.22, Conflicts=6, Conflict Change=0, Moving Queen at Row 0 to Column 7
# Board State: [7, 2, 3, 5, 6, 3, 5, 4]
# Step 343: Temp=3.18, Conflicts=6, Conflict Change=1, Moving Queen at Row 6 to Column 2
# Board State: [7, 2, 3, 5, 6, 3, 5, 4]
# Step 344: Temp=3.15, Conflicts=7, Conflict Change=1, Moving Queen at Row 3 to Column 4
# Board State: [7, 2, 3, 4, 6, 3, 5, 4]
# Step 345: Temp=3.12, Conflicts=7, Conflict Change=0, Moving Queen at Row 5 to Column 0
# Board State: [7, 2, 3, 4, 6, 0, 5, 4]
# Step 346: Temp=3.09, Conflicts=5, Conflict Change=-2, Moving Queen at Row 7 to Column 1
# Board State: [7, 2, 3, 4, 6, 0, 5, 1]
# Step 347: Temp=3.06, Conflicts=6, Conflict Change=1, Moving Queen at Row 3 to Column 2
# Board State: [7, 2, 3, 2, 6, 0, 5, 1]
# Step 348: Temp=3.03, Conflicts=6, Conflict Change=4, Moving Queen at Row 4 to Column 3
# Board State: [7, 2, 3, 2, 6, 0, 5, 1]
# Step 349: Temp=3.00, Conflicts=3, Conflict Change=-3, Moving Queen at Row 3 to Column 6
# Board State: [7, 2, 3, 6, 6, 0, 5, 1]
# Step 350: Temp=2.97, Conflicts=5, Conflict Change=2, Moving Queen at Row 4 to Column 1
# Board State: [7, 2, 3, 6, 1, 0, 5, 1]
# Step 351: Temp=2.94, Conflicts=5, Conflict Change=0, Moving Queen at Row 2 to Column 5
# Board State: [7, 2, 5, 6, 1, 0, 5, 1]
# Step 352: Temp=2.91, Conflicts=4, Conflict Change=-1, Moving Queen at Row 2 to Column 7
# Board State: [7, 2, 7, 6, 1, 0, 5, 1]
# Step 353: Temp=2.88, Conflicts=4, Conflict Change=2, Moving Queen at Row 5 to Column 4
# Board State: [7, 2, 7, 6, 1, 0, 5, 1]
# Step 354: Temp=2.85, Conflicts=6, Conflict Change=2, Moving Queen at Row 6 to Column 0
# Board State: [7, 2, 7, 6, 1, 0, 0, 1]
# Step 355: Temp=2.82, Conflicts=6, Conflict Change=3, Moving Queen at Row 1 to Column 7
# Board State: [7, 2, 7, 6, 1, 0, 0, 1]
# Step 356: Temp=2.79, Conflicts=6, Conflict Change=0, Moving Queen at Row 4 to Column 0
# Board State: [7, 2, 7, 6, 0, 0, 0, 1]
# Step 357: Temp=2.77, Conflicts=3, Conflict Change=-3, Moving Queen at Row 6 to Column 4
# Board State: [7, 2, 7, 6, 0, 0, 4, 1]
# Step 358: Temp=2.74, Conflicts=3, Conflict Change=0, Moving Queen at Row 2 to Column 2
# Board State: [7, 2, 2, 6, 0, 0, 4, 1]
# Step 359: Temp=2.71, Conflicts=3, Conflict Change=4, Moving Queen at Row 6 to Column 2
# Board State: [7, 2, 2, 6, 0, 0, 4, 1]
# Step 360: Temp=2.68, Conflicts=4, Conflict Change=1, Moving Queen at Row 4 to Column 4
# Board State: [7, 2, 2, 6, 4, 0, 4, 1]
# Step 361: Temp=2.66, Conflicts=4, Conflict Change=1, Moving Queen at Row 0 to Column 5
# Board State: [7, 2, 2, 6, 4, 0, 4, 1]
# Step 362: Temp=2.63, Conflicts=3, Conflict Change=-1, Moving Queen at Row 4 to Column 0
# Board State: [7, 2, 2, 6, 0, 0, 4, 1]
# Step 363: Temp=2.60, Conflicts=4, Conflict Change=1, Moving Queen at Row 1 to Column 3
# Board State: [7, 3, 2, 6, 0, 0, 4, 1]
# Step 364: Temp=2.58, Conflicts=4, Conflict Change=0, Moving Queen at Row 4 to Column 4
# Board State: [7, 3, 2, 6, 4, 0, 4, 1]
# Step 365: Temp=2.55, Conflicts=4, Conflict Change=0, Moving Queen at Row 1 to Column 2
# Board State: [7, 2, 2, 6, 4, 0, 4, 1]
# Step 366: Temp=2.53, Conflicts=4, Conflict Change=3, Moving Queen at Row 1 to Column 4
# Board State: [7, 2, 2, 6, 4, 0, 4, 1]
# Step 367: Temp=2.50, Conflicts=3, Conflict Change=-1, Moving Queen at Row 4 to Column 5
# Board State: [7, 2, 2, 6, 5, 0, 4, 1]
# Step 368: Temp=2.48, Conflicts=3, Conflict Change=0, Moving Queen at Row 1 to Column 6
# Board State: [7, 6, 2, 6, 5, 0, 4, 1]
# Step 369: Temp=2.45, Conflicts=4, Conflict Change=1, Moving Queen at Row 0 to Column 6
# Board State: [6, 6, 2, 6, 5, 0, 4, 1]
# Step 370: Temp=2.43, Conflicts=5, Conflict Change=1, Moving Queen at Row 4 to Column 0
# Board State: [6, 6, 2, 6, 0, 0, 4, 1]
# Step 371: Temp=2.40, Conflicts=5, Conflict Change=1, Moving Queen at Row 5 to Column 4
# Board State: [6, 6, 2, 6, 0, 0, 4, 1]
# Step 372: Temp=2.38, Conflicts=7, Conflict Change=2, Moving Queen at Row 4 to Column 6
# Board State: [6, 6, 2, 6, 6, 0, 4, 1]
# Step 373: Temp=2.35, Conflicts=7, Conflict Change=2, Moving Queen at Row 7 to Column 0
# Board State: [6, 6, 2, 6, 6, 0, 4, 1]
# Step 374: Temp=2.33, Conflicts=4, Conflict Change=-3, Moving Queen at Row 4 to Column 5
# Board State: [6, 6, 2, 6, 5, 0, 4, 1]
# Step 375: Temp=2.31, Conflicts=3, Conflict Change=-1, Moving Queen at Row 1 to Column 0
# Board State: [6, 0, 2, 6, 5, 0, 4, 1]
# Step 376: Temp=2.28, Conflicts=6, Conflict Change=3, Moving Queen at Row 2 to Column 0
# Board State: [6, 0, 0, 6, 5, 0, 4, 1]
# Step 377: Temp=2.26, Conflicts=6, Conflict Change=1, Moving Queen at Row 0 to Column 5
# Board State: [6, 0, 0, 6, 5, 0, 4, 1]
# Step 378: Temp=2.24, Conflicts=6, Conflict Change=0, Moving Queen at Row 1 to Column 1
# Board State: [6, 1, 0, 6, 5, 0, 4, 1]
# Step 379: Temp=2.22, Conflicts=6, Conflict Change=2, Moving Queen at Row 0 to Column 0
# Board State: [6, 1, 0, 6, 5, 0, 4, 1]
# Step 380: Temp=2.19, Conflicts=5, Conflict Change=-1, Moving Queen at Row 3 to Column 2
# Board State: [6, 1, 0, 2, 5, 0, 4, 1]
# ...
# Step 550: Temp=0.40, Conflicts=2, Conflict Change=4, Moving Queen at Row 2 to Column 2
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 551: Temp=0.39, Conflicts=2, Conflict Change=2, Moving Queen at Row 3 to Column 6
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 552: Temp=0.39, Conflicts=2, Conflict Change=1, Moving Queen at Row 2 to Column 1
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 553: Temp=0.39, Conflicts=2, Conflict Change=2, Moving Queen at Row 4 to Column 7
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 554: Temp=0.38, Conflicts=2, Conflict Change=3, Moving Queen at Row 1 to Column 4
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 555: Temp=0.38, Conflicts=2, Conflict Change=2, Moving Queen at Row 4 to Column 4
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 556: Temp=0.37, Conflicts=2, Conflict Change=1, Moving Queen at Row 1 to Column 1
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 557: Temp=0.37, Conflicts=2, Conflict Change=1, Moving Queen at Row 5 to Column 7
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 558: Temp=0.37, Conflicts=2, Conflict Change=2, Moving Queen at Row 7 to Column 2
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 559: Temp=0.36, Conflicts=2, Conflict Change=3, Moving Queen at Row 1 to Column 6
# Board State: [4, 7, 5, 2, 2, 6, 6, 3]
# Step 560: Temp=0.36, Conflicts=1, Conflict Change=-1, Moving Queen at Row 3 to Column 0
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 561: Temp=0.36, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 562: Temp=0.35, Conflicts=1, Conflict Change=2, Moving Queen at Row 7 to Column 0
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 563: Temp=0.35, Conflicts=1, Conflict Change=3, Moving Queen at Row 3 to Column 6
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 564: Temp=0.35, Conflicts=1, Conflict Change=1, Moving Queen at Row 0 to Column 2
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 565: Temp=0.34, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 7
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 566: Temp=0.34, Conflicts=1, Conflict Change=3, Moving Queen at Row 4 to Column 7
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 567: Temp=0.34, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 1
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 568: Temp=0.33, Conflicts=1, Conflict Change=3, Moving Queen at Row 4 to Column 4
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 569: Temp=0.33, Conflicts=1, Conflict Change=3, Moving Queen at Row 3 to Column 6
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 570: Temp=0.33, Conflicts=1, Conflict Change=1, Moving Queen at Row 7 to Column 1
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 571: Temp=0.32, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 1
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 572: Temp=0.32, Conflicts=1, Conflict Change=3, Moving Queen at Row 1 to Column 2
# Board State: [4, 7, 5, 0, 2, 6, 6, 3]
# Step 573: Temp=0.32, Conflicts=1, Conflict Change=0, Moving Queen at Row 5 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 574: Temp=0.31, Conflicts=1, Conflict Change=1, Moving Queen at Row 5 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 575: Temp=0.31, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 576: Temp=0.31, Conflicts=1, Conflict Change=2, Moving Queen at Row 7 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 577: Temp=0.30, Conflicts=1, Conflict Change=2, Moving Queen at Row 0 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 578: Temp=0.30, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 579: Temp=0.30, Conflicts=1, Conflict Change=2, Moving Queen at Row 6 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 580: Temp=0.29, Conflicts=1, Conflict Change=3, Moving Queen at Row 6 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 581: Temp=0.29, Conflicts=1, Conflict Change=2, Moving Queen at Row 7 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 582: Temp=0.29, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 583: Temp=0.29, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 584: Temp=0.28, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 585: Temp=0.28, Conflicts=1, Conflict Change=2, Moving Queen at Row 0 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 586: Temp=0.28, Conflicts=1, Conflict Change=3, Moving Queen at Row 1 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 587: Temp=0.27, Conflicts=1, Conflict Change=1, Moving Queen at Row 4 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 588: Temp=0.27, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 589: Temp=0.27, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 590: Temp=0.27, Conflicts=1, Conflict Change=2, Moving Queen at Row 6 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 591: Temp=0.26, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 592: Temp=0.26, Conflicts=1, Conflict Change=1, Moving Queen at Row 7 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 593: Temp=0.26, Conflicts=1, Conflict Change=3, Moving Queen at Row 6 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 594: Temp=0.26, Conflicts=1, Conflict Change=2, Moving Queen at Row 6 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 595: Temp=0.25, Conflicts=1, Conflict Change=1, Moving Queen at Row 0 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 596: Temp=0.25, Conflicts=1, Conflict Change=2, Moving Queen at Row 0 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 597: Temp=0.25, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 598: Temp=0.25, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 599: Temp=0.24, Conflicts=1, Conflict Change=2, Moving Queen at Row 7 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 600: Temp=0.24, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 601: Temp=0.24, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 602: Temp=0.24, Conflicts=1, Conflict Change=3, Moving Queen at Row 7 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 603: Temp=0.23, Conflicts=1, Conflict Change=3, Moving Queen at Row 4 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 604: Temp=0.23, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 605: Temp=0.23, Conflicts=1, Conflict Change=1, Moving Queen at Row 7 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 606: Temp=0.23, Conflicts=1, Conflict Change=1, Moving Queen at Row 1 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 607: Temp=0.22, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 608: Temp=0.22, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 609: Temp=0.22, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 610: Temp=0.22, Conflicts=1, Conflict Change=3, Moving Queen at Row 2 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 611: Temp=0.22, Conflicts=1, Conflict Change=2, Moving Queen at Row 6 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 612: Temp=0.21, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 613: Temp=0.21, Conflicts=1, Conflict Change=3, Moving Queen at Row 4 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 614: Temp=0.21, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 615: Temp=0.21, Conflicts=1, Conflict Change=1, Moving Queen at Row 5 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 616: Temp=0.20, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 617: Temp=0.20, Conflicts=1, Conflict Change=2, Moving Queen at Row 3 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 618: Temp=0.20, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 619: Temp=0.20, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 620: Temp=0.20, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 621: Temp=0.19, Conflicts=1, Conflict Change=2, Moving Queen at Row 3 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 622: Temp=0.19, Conflicts=1, Conflict Change=3, Moving Queen at Row 6 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 623: Temp=0.19, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 624: Temp=0.19, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 625: Temp=0.19, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 626: Temp=0.19, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 627: Temp=0.18, Conflicts=1, Conflict Change=3, Moving Queen at Row 6 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 628: Temp=0.18, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 629: Temp=0.18, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 630: Temp=0.18, Conflicts=1, Conflict Change=2, Moving Queen at Row 6 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 631: Temp=0.18, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 632: Temp=0.17, Conflicts=1, Conflict Change=1, Moving Queen at Row 5 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 633: Temp=0.17, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 634: Temp=0.17, Conflicts=1, Conflict Change=1, Moving Queen at Row 0 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 635: Temp=0.17, Conflicts=1, Conflict Change=3, Moving Queen at Row 7 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 636: Temp=0.17, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 637: Temp=0.17, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 638: Temp=0.16, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 6
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 639: Temp=0.16, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 640: Temp=0.16, Conflicts=1, Conflict Change=3, Moving Queen at Row 6 to Column 4
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 641: Temp=0.16, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 3
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 642: Temp=0.16, Conflicts=1, Conflict Change=3, Moving Queen at Row 7 to Column 5
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 643: Temp=0.16, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 644: Temp=0.15, Conflicts=1, Conflict Change=1, Moving Queen at Row 5 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 645: Temp=0.15, Conflicts=1, Conflict Change=2, Moving Queen at Row 6 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 646: Temp=0.15, Conflicts=1, Conflict Change=2, Moving Queen at Row 1 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 647: Temp=0.15, Conflicts=1, Conflict Change=2, Moving Queen at Row 0 to Column 7
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 648: Temp=0.15, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 649: Temp=0.15, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 650: Temp=0.15, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 1
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 651: Temp=0.14, Conflicts=1, Conflict Change=1, Moving Queen at Row 0 to Column 2
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 652: Temp=0.14, Conflicts=1, Conflict Change=3, Moving Queen at Row 2 to Column 0
# Board State: [4, 7, 5, 0, 2, 0, 6, 3]
# Step 653: Temp=0.14, Conflicts=1, Conflict Change=0, Moving Queen at Row 0 to Column 1
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 654: Temp=0.14, Conflicts=1, Conflict Change=1, Moving Queen at Row 1 to Column 3
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 655: Temp=0.14, Conflicts=1, Conflict Change=3, Moving Queen at Row 0 to Column 6
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 656: Temp=0.14, Conflicts=1, Conflict Change=1, Moving Queen at Row 7 to Column 6
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 657: Temp=0.14, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 6
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 658: Temp=0.13, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 3
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 659: Temp=0.13, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 2
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 660: Temp=0.13, Conflicts=1, Conflict Change=1, Moving Queen at Row 6 to Column 5
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 661: Temp=0.13, Conflicts=1, Conflict Change=2, Moving Queen at Row 0 to Column 7
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 662: Temp=0.13, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 6
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 663: Temp=0.13, Conflicts=1, Conflict Change=3, Moving Queen at Row 4 to Column 1
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 664: Temp=0.13, Conflicts=1, Conflict Change=1, Moving Queen at Row 5 to Column 7
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 665: Temp=0.13, Conflicts=1, Conflict Change=2, Moving Queen at Row 4 to Column 3
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 666: Temp=0.12, Conflicts=1, Conflict Change=3, Moving Queen at Row 2 to Column 0
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 667: Temp=0.12, Conflicts=1, Conflict Change=2, Moving Queen at Row 2 to Column 1
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 668: Temp=0.12, Conflicts=1, Conflict Change=3, Moving Queen at Row 6 to Column 0
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 669: Temp=0.12, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 3
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 670: Temp=0.12, Conflicts=1, Conflict Change=1, Moving Queen at Row 5 to Column 6
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 671: Temp=0.12, Conflicts=1, Conflict Change=2, Moving Queen at Row 5 to Column 5
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 672: Temp=0.12, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 5
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 673: Temp=0.12, Conflicts=1, Conflict Change=1, Moving Queen at Row 3 to Column 1
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 674: Temp=0.11, Conflicts=1, Conflict Change=1, Moving Queen at Row 2 to Column 4
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 675: Temp=0.11, Conflicts=1, Conflict Change=2, Moving Queen at Row 0 to Column 5
# Board State: [1, 7, 5, 0, 2, 0, 6, 3]
# Step 676: Temp=0.11, Conflicts=0, Conflict Change=-1, Moving Queen at Row 5 to Column 4
# Board State: [1, 7, 5, 0, 2, 4, 6, 3]
# Step 677: Solution found!
# Board State: [1, 7, 5, 0, 2, 4, 6, 3]
# Final Solution: [1, 7, 5, 0, 2, 4, 6, 3]
